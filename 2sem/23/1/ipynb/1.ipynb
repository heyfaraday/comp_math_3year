# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as interp
# %matplotlib inline

# %%
t_1, result_1_z = np.genfromtxt("../result_1_z").T
t_1, result_1_x = np.genfromtxt("../result_1_x").T
t_4, result_4_z = np.genfromtxt("../result_4_z").T
t_4, result_4_x = np.genfromtxt("../result_4_x").T

# %%
plt.figure(figsize=(10, 10))
plt.title('ε = 4')
RK1, = plt.plot(result_1_z, result_1_x, 'b--', label = 'RK1')
RK4, = plt.plot(result_4_z, result_4_x, 'r--', label = 'RK4')
# Analytical, = plt.plot(- np.sin(t) +  np.cos(t), np.sin(t) +  np.cos(t), 'g--', label = 'Analytical')
first_legend = plt.legend(handles=[RK1, RK4], loc=2)

plt.show()

plt.figure(figsize=(10, 10))
plt.title('ε = 4')
RK1, = plt.plot(t_1, result_1_x, 'b--', label = 'RK1')
RK4, = plt.plot(t_4, result_4_x, 'r--', label = 'RK4')
# Analytical, = plt.plot(t, np.sin(t) +  np.cos(t), 'g--', label = 'Analytical')
first_legend = plt.legend(handles=[RK1, RK4], loc=2)

plt.show()

# %%
result_1_x.size
# Out:
# 10207
