# %%
import numpy as np

# %%
def grad_f(x):
    return np.array([3. * x[0] * x[0] - 3 * x[1], 3. * x[1] * x[1] - 3 * x[0]])
def f(x):
    return np.exp(x[0] + 3 * x[1] - 0.1) + np.exp(x[0] - 3 * x[1] - 0.1) + np.exp(- x[0] - 0.1)

# %%
import matplotlib.pyplot as plt

x_0 = np.array([3, 3])
v_0 = np.array([0., 0.])

x = np.arange(-4, 2, 0.05)
y = np.arange(-2.1, 2.1, 0.05)
xgrid, ygrid = np.meshgrid(x, y)

zgrid = np.log(f(np.array([xgrid, ygrid])))

plt.figure(figsize=(15, 15))
plt.contour(xgrid, ygrid, zgrid, 50)
plt.scatter([-1], [2], marker='o', s=20, c='r')
plt.scatter(x_1_1, x_2_1, marker='o', s=20, c='g')
plt.scatter(x_1_2, x_2_2, marker='o', s=20, c='orange')
plt.scatter(x_1_3[:5], x_2_3[:5], marker='o', s=20, c='b')

# for i in range(0, number_of_iterations):
#     plt.scatter([x_0[0]], [x_0[1]], marker='o', s=20, c='r')
#     v_dash = v_0 - grad_f(x_0) * tau
#     v_0 = beta * v_dash
#     x_0 = x_0 + v_0 * tau
    
#     print(x_0)

plt.show()

# %% [markdown]
# ## f([-1, 2])

# %%
import numpy as np
from numpy import *
from pylab import *

# %%
x_1_3 = genfromtxt(
    "cmake-build-debug/x_1_3.txt").T
x_2_3 = genfromtxt(
    "cmake-build-debug/x_2_3.txt").T
f_x_3 = genfromtxt(
    "cmake-build-debug/f_x_3.txt").T

# %%
x_1_2 = genfromtxt(
    "cmake-build-debug/x_1_2.txt").T
x_2_2 = genfromtxt(
    "cmake-build-debug/x_2_2.txt").T
f_x_2 = genfromtxt(
    "cmake-build-debug/f_x_2.txt").T

# %%
x_1_1 = genfromtxt(
    "cmake-build-debug/x_1_1.txt").T
x_2_1 = genfromtxt(
    "cmake-build-debug/x_2_1.txt").T
f_x_1 = genfromtxt(
    "cmake-build-debug/f_x_1.txt").T

# %%
import pandas as pd
import numpy as np

import plotly.plotly as py
import plotly.graph_objs as go

from scipy import optimize as opt 
import scipy
import scipy.odr as odr

from statsmodels.stats.weightstats import *

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning:
#
# pylab import has clobbered these variables: ['linalg', 'random', 'power', 'fft', 'info']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# trace1 = go.Scatter(
#     y = f_x_3,
#     x = n,
#     mode = 'markers',
#     name = '$~~~~~τ^{~1}~=~3 \cdot 10^{-7}$',
# )

# trace2 = go.Scatter(
#     y = f_x_2,
#     x = n,
#     mode = 'markers',
#     name = '$~~~~~τ^{~1}~=~2 \cdot 10^{-7}$',
# )

trace3 = go.Scatter(
    y = f_x_1[:8],
    x = np.arange(1, f_x_1.size + 1, 1)[:8],
    mode = 'markers',
    marker = dict(
        size = 10,
    )
#     name = '$~~~~~τ^{~1}~=~1 \cdot 10^{-7}$',
)

# trace4 = go.Scatter(
#     y = 2.55927 * n / n,
#     x = n,
# #     mode = 'markers',
#     name = '$~~~~~f_{min}~=~2.55927$',
#     line = dict(
#         width = 6,
#         dash = 'dot')
# )


trace0 = [trace3]

layout = go.Layout(
#     showlegend=True,
    legend=dict(
        x=0.1,
        y=0.8
        #orientation= "h"
    ),
    title = "Functional",
    width = 1500,
    height = 1500,
    font = dict(
        size = 30,
        color = '#000000'
        ),
    paper_bgcolor = '#ffffff',
    xaxis = dict(
        title = '$n$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    yaxis = dict(
        title = '$f(x^{n})$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    margin = dict(
        l = 100,
        r = 23,
        t = 70,
        b = 100,
        pad = 0 
    ),
)

fig = go.Figure(data=trace0, layout=layout)
#py.iplot(figure, filename='basic-error-bar')
py.image.save_as(fig, '1.png')
#! open my_plot.png
from IPython.display import Image
Image("1.png", width=500)
