# %%
from numpy import *
from pylab import *

# %%
x_1 = genfromtxt(
    "cmake-build-debug/res_1.dat").T
x_2 = genfromtxt(
    "cmake-build-debug/res_2.dat").T
x_015 = genfromtxt(
    "cmake-build-debug/res_1_0.15.dat").T
x_016 = genfromtxt(
    "cmake-build-debug/res_1_0.20.dat").T

x_010 = genfromtxt(
    "cmake-build-debug/res_1_0.1.dat").T
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-f5f1be1e669b> in <module>()
#       1 x_1 = genfromtxt(
# ----> 2     "cmake-build-debug/res_1.dat").T
#       3 x_2 = genfromtxt(
#       4     "cmake-build-debug/res_2.dat").T
#       5 x_015 = genfromtxt(
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1508         if isinstance(fname, basestring):
#    1509             if sys.version_info[0] == 2:
# -> 1510                 fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1511             else:
#    1512                 fhd = iter(np.lib._datasource.open(fname, 'rb'))
#
# ...

# %%
import pandas as pd
import numpy as np

import plotly.plotly as py
import plotly.graph_objs as go

from scipy import optimize as opt 
import scipy
import scipy.odr as odr

from statsmodels.stats.weightstats import *

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/heyfaraday/anaconda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning:
#
# pylab import has clobbered these variables: ['fft', 'power', 'random', 'linalg', 'info']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
size(k)
# Out:
# 1201

# %%
trace1 = go.Scatter(
    y = x_1,
    x = np.arange(1, size(x_1)),
    mode = 'markers',
    name = '$~~~~~τ^{~mpi}~=~0.15$',
)

trace2 = go.Scatter(
    y = x_2,
    x = np.arange(1, size(x_2)),
    mode = 'markers',
    name = '$~~~~~τ^{~jac}~=~1.0$',
)

trace0 = [trace1, trace2]

layout = go.Layout(
    showlegend=True,
    legend=dict(
        x=0.1,
        y=0.8
        #orientation= "h"
    ),
    title = "1",
    width = 1500,
    height = 1500,
    font = dict(
        size = 30,
        color = '#000000'
        ),
    paper_bgcolor = '#ffffff',
    xaxis = dict(
        title = '$k$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    yaxis = dict(
        title = '$||r_k|| / ||r_0||$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    margin = dict(
        l = 100,
        r = 23,
        t = 70,
        b = 100,
        pad = 0 
    ),
)

fig = go.Figure(data=trace0, layout=layout)
#py.iplot(figure, filename='basic-error-bar')
py.image.save_as(fig, '1.png')
#! open my_plot.png
from IPython.display import Image
Image("1.png", width=500)

# %%
trace1 = go.Scatter(
    y = x_010,
    x = np.arange(1, size(x_010)),
    mode = 'markers',
    name = '$~~~~~τ^{~mpi}~=~0.10$',
)

trace2 = go.Scatter(
    y = x_015,
    x = np.arange(1, size(x_015)),
    mode = 'markers',
    name = '$~~~~~τ^{~mpi}~=~0.15$',
)

trace3 = go.Scatter(
    y = x_016,
    x = np.arange(1, size(x_016)),
    mode = 'markers',
    name = '$~~~~~τ^{~mpi}~=~0.16$',
)

trace0 = [trace1, trace2, trace3]

layout = go.Layout(
    showlegend=True,
    legend=dict(
        x=0.1,
        y=0.8
        #orientation= "h"
    ),
    title = "2",
    width = 1500,
    height = 1500,
    font = dict(
        size = 30,
        color = '#000000'
        ),
    paper_bgcolor = '#ffffff',
    xaxis = dict(
        title = '$k$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    yaxis = dict(
        title = '$||r_k|| / ||r_0||$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    margin = dict(
        l = 100,
        r = 23,
        t = 70,
        b = 100,
        pad = 0 
    ),
)

fig = go.Figure(data=trace0, layout=layout)
#py.iplot(figure, filename='basic-error-bar')
py.image.save_as(fig, '2.png')
#! open my_plot.png
from IPython.display import Image
Image("2.png", width=500)

# %%
x_10 = genfromtxt(
    "cmake-build-debug/res_2_1.0.dat").T
x_05 = genfromtxt(
    "cmake-build-debug/res_2_0.5.dat").T
x_07 = genfromtxt(
    "cmake-build-debug/res_2_0.7.dat").T

# %%
trace1 = go.Scatter(
    y = x_10,
    x = np.arange(1, size(x_10)),
    mode = 'markers',
    name = '$~~~~~τ^{~jac}~=~1.0$',
)

trace2 = go.Scatter(
    y = x_05,
    x = np.arange(1, size(x_10)),
    mode = 'markers',
    name = '$~~~~~τ^{~jac}~=~0.5$',
)

trace3 = go.Scatter(
    y = x_07,
    x = np.arange(1, size(x_10)),
    mode = 'markers',
    name = '$~~~~~τ^{~jac}~=~0.7$',
)

trace0 = [trace1, trace2, trace3]

layout = go.Layout(
    showlegend=True,
    legend=dict(
        x=0.1,
        y=0.9
        #orientation= "h"
    ),
    title = "3",
    width = 1500,
    height = 1500,
    font = dict(
        size = 30,
        color = '#000000'
        ),
    paper_bgcolor = '#ffffff',
    xaxis = dict(
        title = '$k$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    yaxis = dict(
        title = '$||r_k|| / ||r_0||$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    margin = dict(
        l = 100,
        r = 23,
        t = 70,
        b = 100,
        pad = 0 
    ),
)

fig = go.Figure(data=trace0, layout=layout)
#py.iplot(figure, filename='basic-error-bar')
py.image.save_as(fig, '3.png')
#! open my_plot.png
from IPython.display import Image
Image("3.png", width=500)

# %%
solve_1 = genfromtxt(
    "cmake-build-debug/x_out_1.dat").T
solve_2 = genfromtxt(
    "cmake-build-debug/x_out_2.dat").T

# %%
trace1 = go.Scatter(
    y = solve_1,
    x = np.arange(1, size(solve_1)),
    mode = 'markers',
    name = '$~~~~~τ^{~jac}~=~1.0$',
)

# trace2 = go.Scatter(
#     y = solve_2,
#     x = np.arange(1, size(solve_2)),
#     mode = 'markers',
#     name = '$~~~~~τ^{~jac}~=~0.5$',
# )

trace0 = [trace1]

layout = go.Layout(
    showlegend=False,
    title = "4",
    width = 1500,
    height = 1500,
    font = dict(
        size = 30,
        color = '#000000'
        ),
    paper_bgcolor = '#ffffff',
    xaxis = dict(
        title = '$i$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    yaxis = dict(
        title = '$x$',
        zeroline = False,
        ticklen = 0,
        color = '#000000',
        mirror = True,
        showline = True,
        linewidth = 2,
        titlefont = dict(
            size = 40,
            color = '#000000' 
            )
    ),
    margin = dict(
        l = 100,
        r = 23,
        t = 70,
        b = 100,
        pad = 0 
    ),
)

fig = go.Figure(data=trace0, layout=layout)
#py.iplot(figure, filename='basic-error-bar')
py.image.save_as(fig, '4.png')
#! open my_plot.png
from IPython.display import Image
Image("4.png", width=500)
